# %% [markdown]
# # Exercise 10
#
# Related Notes:
# - Chapter_10_SQL-Databases
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/njc-cz2-2021/Materials/blob/main/Exercises/Exercise_10_SQL_Databases.ipynb)

# %% [markdown]
# ## Exercise 10.1 2019/A Level/P2/Q2 H2 Computing
# A bakery bakes bread and cakes to sell in its own shop and to other shops throughout a city. Its drivers visit every shop each day, delivering that day’s order and collecting the order for the next day.
# Order forms are pre-printed with the name of each shop and every item that the bakery bakes. The manager of each shop writes onto the form the quantity of each item required. When the drivers return to the bakery. the data from the order forms are collated to give the bakers the total of each item to bake.
# Copies of the order forms are made and used as delivery notes for the next day’s deliveries. The accounts department use the original order forms to prepare a weekly invoice for each shop.
#
# The bakery wants the shops to submit their orders online.
#
# A program is needed to determine the number of each item needed and produce the weekly invoice for each shop.
#
# The new program will use a relational database with three tables: Product, Shop and Order.
#
# Each product has a description. price. and a unique product ID number.
#
# Each shop has a name. an address, telephone number. manager's name, and a unique shop iD number.
#
# Each order has a product lD, a quantity, a shop ID and a date for delivery.
#
# 1. Draw an Entity-Relationship (E-R) diagram showing the three tables and the relationships between them.
# <div style="text-align: right">[5]</div>
#
# 2. A table description can be expressed as: <br>
# <br>
#     $\text{TableName}\left(\underline{\text{Attribute1}},\text{ Attribute2, Attribute3, }\dots \right )$ <br>
#     <br>
#     The primary key is indicated by underlining one or more attributes. <br>
#     <br>
#     Write table descriptions for the three tables.
# <div style="text-align: right">[4]</div>
#
# The bakery can change the price of an item at any time. Validation ensures that the new price is within specified limits and is more likely to be correct.
#
# 3. i. Explain why this could still result in incorrect weekly invoices, assuming that the new price input is correct. <br>
#     <div style="text-align: right">[2]</div>
#     ii. Describe changes to the database and draw a modified E-R diagram to ensure correct invoices are created. <br>
#         <div style="text-align: right">[4]</div>

# %% [markdown]
# # 1
# <center>
# <img src="Diagrams/10_1_Q1.svg">
# </center>
# <br>
# <center>
# <img src="Diagrams/10_1_Q1_idk.svg">
# </center>
#
# # 2
# $$\text{Product}\left(\underline{\text{productIdNumber}}\text{, description, price}\right) $$
#
# $$\text{Shop}\left( \underline{\text{shopIdNumber}} \text{, name, address, telephone number, managerName} \right)$$
#
# $$\text{Order}\left( \underline{\text{shopIdNumber}}\text{, } \underline{\text{productIdNumber}} \text{, dateOfDelivery, quantity} \right)$$
#
# # 3
# ## (i)
# The shops should be charged for the price that they ordered the product for and not the newest price. The current design of the relational database only keeps track of the newest price of the products and thus, when the bakery changes the price, the shops would be paying the newest price and not the original price that they ordered the product at.
#
# ## (ii)
# To prevent this discrepancy, the Order table should also keep track of the price of the product at the time of order.
# <center>
# <img src="Diagrams/10_1_Q3.svg">
# </center>

# %% [markdown]
# ## Exercise 10.2 2017/A Level/P2/Q6 H2 Computing
# A computer company has several offices throughout the country, each with several salespersons. A record of the sales made by each salesperson has been set up using a relational database.
# There is a minimum amount of $150 for each sale.
#
# The following tables hold the data.
#
# $\text{CUSTOMER (\underline{\text{CustomerID}}, CustomerName, CustomerEmail, CustomerTelephone)}$<br>
# $\text{OFFICE (\underline{\text{OfficeID}}, Address, Telephone)}$<br>
# $\text{SALE (\underline{\text{CustomerID*}}, \underline{\text{SalesPersonID*}}, SaleDate, Amount)}$<br>
# $\text{SALESPERSON (\underline{\text{SalesPersonID}}, SalespersonName, OfficeID*)}$
#
# Note: underline indicates primary key. An asterisk (*) indicates a foreign key.
#
# - (a) Draw an Entity-Relationship (E-R) diagram to represent the data model.
#     <div style="text-align: right">[3]</div>
# - (b) The following is a section of the data dictionary for the data model. It has three missing entries labelled **A**, **B** and **C**.
#     <center>
#
#     | Table | Field  | Data type| Validation
#     |-|-|-|-|
#     | `CUSTOMER` |`CustomerID` | Integer| Unique
#     |`SALE`| `CustomerID`|Integer| **A**
#     |`SALE`| `Saledate`| Date |
#     |`SALE`| `Amount`| **B**| **C**
#
#     </center>
#
#     State a suitable entry for A, B and C.
#     <div style="text-align: right">[3]</div>
# - (c) There is an address field in this database.
#     Explain why storing the address as a single field is not good database design.
#     <div style="text-align: right">[3]</div>
# Each month, a report is produced to show the sales for each salesperson. The following is a report for salesperson, B Chin.
#
# <center>
# <img src="img/database-bchin.png" width="600" align="center"/>
# </center>
#
# - (d) (i) To produce the report, the database uses the SaleDate and Amount fields in the SALE table.
#     Name four other fields that the database uses to produce this report.
#     <div style="text-align: right">[4]</div>
# - (d) (ii) State two features of a relational database management system which would be used to calculate and display the total for this salesperson.
#     <div style="text-align: right">[2]</div>

# %% [markdown]
# # (a)
# <center>
# <img src="Diagrams/10_2_A.svg">
# </center>
#
# # (b)
# A -> Not Unique
# B -> Integer
# C -> Not Unique
#
# # (c)
# If the address contains multiple sets of information such as postal code, street address and Country, placing it all in one single field will not allow the table to achieve atomicity in its data. To achieve any normalisation form, all data stored in the database must be atomic, that is, only a singular piece of data in a field
#
# # (d)
# ## (i)
# SALE table:
# - CustomerID
# - SalesPersonID
#
# CUSTOMER table:
# - CustomerName
#
# SALESPERSON table:
# - SalesPersonName
#
# ## (ii)
# To calculate and display the total for this salesperson, the two features of a relational database management system which are used are data manipulation language for the inserting and amending of data and a data dictionary which includes the rules about data integrity including validation rules for all attributes.

# %%
import sqlite3

conn = sqlite3.connect('10_2.db')
cursor = conn.cursor()

cursor.execute("PRAGMA table_info(CUSTOMER)")
columns_info = cursor.fetchall()

column_names = [i[1] for i in columns_info]
print(column_names)
print(columns_info)
# Out:
# ['CustomerID', 'CustomerName', 'CustomerEmail', 'CustomerTelephone']
# [(0, 'CustomerID', 'INTEGER', 0, None, 1), (1, 'CustomerName', 'TEXT', 1, None, 0), (2, 'CustomerEmail', 'TEXT', 1, None, 0), (3, 'CustomerTelephone', 'INTEGER', 1, None, 0)]

# %% [markdown]
# ## Exercise 10.3
# Open the file `poly.db` found under the `resources` folder.
# It contains information from Temasek Polytechnic Full-Time Enrolment Figures Breakdown, Annual dataset accessed on 23 March 2018 from Temasek Polytechnic which is made available under the terms of the Singapore Open Data Licence version 1.0 (http://www.data.gov.sg)
# The database provides the enrolment in different polytechnic courses in Temasek Polytechnic (TP) by year and gender.
#
# Try to give the SQL statement to generate the following.
#
# 1.	List the courses in TP that has more than 250 males in 2017.
# 2.	List the courses in TP that has no more than 50 females in 2016.
# 3.	List out all fields in the table for courses not in School of Informatics & IT in 2016.
# 4.	List the largest number of female(s) in a course in 2017.
# 5.	List the smallest number of male(s) in a course in 2016.
# 6.	Rename the all diplomas called ‘Diploma in Cyber & Digital Security’ to ‘Diploma in Cyber and Digital Security’.
# 7.	Update the table to add 5 students to each gender and each course in School of Design in 2017.

# %%
#YOUR_ANSWER_HEREimport sqlite3

SELECT course_name FROM enrolment WHERE year = 2017 AND gender = "Male" AND count >250

SELECT course_name FROM enrolment WHERE year = 2016 AND gender = "Female" AND count <= 50

SELECT * FROM enrolment where school <> "School of Informatics & IT" and year = 2016

SELECT MAX(count) FROM enrolment where gender = "Female" and year = 2017

SELECT MIN(count) FROM enrolment where gender = "Male" and year = 2016

UPDATE enrolment SET course_name = "Diploma in Cyber and Digital Security" WHERE course_name = "Diploma in Cypher & Digital Security"

UPDATE enrolment SET count = count + 5 WHERE course_name = "School of Design" and year = 2017

# %% [markdown]
# ## Exercise 10.4
# Repeat Exercise 10.2 using the `sqlite3` module in Python.

# %%
import sqlite3

sql_commands = [
    "CREATE TABLE IF NOT EXISTS CUSTOMER(CustomerID INTEGER PRIMARY KEY AUTOINCREMENT, CustomerName TEXT NOT NULL, CustomerEmail TEXT NOT NULL, CustomerTelephone INTEGER NOT NULL)",
    "CREATE TABLE IF NOT EXISTS OFFICE(OfficeID INTEGER PRIMARY KEY AUTOINCREMENT, Address TEXT NOT NULL, Telephone INTEGER NOT NULL, PRIMARY KEY(officeID,Address))",
    "CREATE TABLE IF NOT EXISTS SALE(CustomerID NOT NULL REFERENCES CUSTOMER(CustomerID), SalesPersonID NOT NULL REFERENCES SALESPERSON(SalesPersonID), SaleDate DATE NOT NULL, Amount INTEGER NOT NULL)",
    "CREATE TABLE IF NOT EXISTS SALESPERSON(SalesPersonID INTEGER AUTOINCREMENT NOT NULL, SalesPersonName Text Not NULL, OfficeID NOT NULL REFERENCES OFFICE(officeID))"
]

conn = sqlite3.connect("10_2.db")
cursor = conn.cursor()
for i in sql_commands:
    cursor.execute(i)

conn.commit()
conn.close()

# %%
import sqlite3

sql_commands = [
    "SELECT course_name FROM enrolment WHERE year = 2017 AND gender = 'Male' AND count >250",
    "SELECT course_name FROM enrolment WHERE year = 2016 AND gender = 'Female' AND count <= 50",
    "SELECT * FROM enrolment where school <> 'School of Informatics & IT' and year = 2016",
    "SELECT MAX(count) FROM enrolment where gender = 'Female' and year = 2017",
    "SELECT MIN(count) FROM enrolment where gender = 'Male' and year = 2016",
    "UPDATE enrolment SET course_name = 'Diploma in Cyber and Digital Security' WHERE course_name = 'Diploma in Cypher & Digital Security'",
    "UPDATE enrolment SET count = count + 5 WHERE course_name = 'School of Design' and year = 2017"    
]

conn = sqlite3.connect("C:/Users/ryan_/Downloads/School/Resources/H2 Computing/Materials-Personal/Exercises/resources/poly.db")
cursor = conn.cursor()
for command in sql_commands:
    cursor.execute(command)
    print(f"Executing: {command}")
    if data := cursor.fetchall():
        print("\n".join([str(i) for i in list(data)]))
        print()
    else:
        pass
conn.commit()
conn.close()
# Out:
# Executing: SELECT course_name FROM enrolment WHERE year = 2017 AND gender = 'Male' AND count >250
# ('Diploma in Chemical Engineering',)
# ('Diploma in Aerospace Electronics',)
# ('Diploma in Aerospace Engineering',)
# ('Diploma in Aviation Management & Services',)
# ('Diploma in Mechatronics',)
#
# Executing: SELECT course_name FROM enrolment WHERE year = 2016 AND gender = 'Female' AND count <= 50
# ('Diploma in Consumer Science & Technology',)
# ('Diploma in Visual Communication',)
# ('Common Engineering Programme',)
# ('Diploma in Aerospace Engineering',)
# ('Diploma in Computer Engineering',)
# ('Diploma in Media & Communication Technology',)
# ('Diploma in Microelectronics',)
# ('Electrical & Electronic Engineering Programme',)
# ('Mechatronics/Aerospace Engineering',)
# ('Diploma in Big Data Management & Governance',)
# ('Diploma in Cyber and Digital Security',)
# ('Diploma in Game Design & Development',)
#
# Executing: SELECT * FROM enrolment where school <> 'School of Informatics & IT' and year = 2016
# (2016, 'School of Applied Science', 'Diploma in Applied Food Science & Nutrition', 'Female', 242)
# (2016, 'School of Applied Science', 'Diploma in Applied Food Science & Nutrition', 'Male', 58)
# (2016, 'School of Applied Science', 'Diploma in Baking & Culinary Science', 'Female', 60)
# (2016, 'School of Applied Science', 'Diploma in Baking & Culinary Science', 'Male', 66)
# (2016, 'School of Applied Science', 'Diploma in Biomedical Science', 'Female', 94)
# (2016, 'School of Applied Science', 'Diploma in Biomedical Science', 'Male', 56)
# (2016, 'School of Applied Science', 'Diploma in Biotechnology', 'Female', 163)
# (2016, 'School of Applied Science', 'Diploma in Biotechnology', 'Male', 113)
# (2016, 'School of Applied Science', 'Diploma in Chemical Engineering', 'Female', 159)
# (2016, 'School of Applied Science', 'Diploma in Chemical Engineering', 'Male', 292)
# (2016, 'School of Applied Science', 'Diploma in Consumer Science & Technology', 'Female', 5)
# (2016, 'School of Applied Science', 'Diploma in Pharmaceutical Science', 'Female', 183)
# (2016, 'School of Applied Science', 'Diploma in Pharmaceutical Science', 'Male', 107)
# (2016, 'School of Applied Science', 'Diploma in Veterinary Technology', 'Female', 112)
# (2016, 'School of Applied Science', 'Diploma in Veterinary Technology', 'Male', 42)
# (2016, 'School of Business', 'Business/ Logistics & Operations Management/Marketing', 'Female', 273)
# (2016, 'School of Business', 'Business/ Logistics & Operations Management/Marketing', 'Male', 203)
# (2016, 'School of Business', 'Diploma in Accounting & Finance', 'Female', 232)
# (2016, 'School of Business', 'Diploma in Accounting & Finance', 'Male', 245)
# (2016, 'School of Business', 'Diploma in Business', 'Female', 380)
# (2016, 'School of Business', 'Diploma in Business', 'Male', 261)
# (2016, 'School of Business', 'Diploma in Business Information Technology', 'Female', 180)
# (2016, 'School of Business', 'Diploma in Business Information Technology', 'Male', 210)
# (2016, 'School of Business', 'Diploma in Communications & Media Management', 'Female', 192)
# (2016, 'School of Business', 'Diploma in Communications & Media Management', 'Male', 66)
# (2016, 'School of Business', 'Diploma in Culinary & Catering Management', 'Female', 78)
# (2016, 'School of Business', 'Diploma in Culinary & Catering Management', 'Male', 83)
# (2016, 'School of Business', 'Diploma in Hospitality & Tourism Management', 'Female', 461)
# (2016, 'School of Business', 'Diploma in Hospitality & Tourism Management', 'Male', 195)
# (2016, 'School of Business', 'Diploma in Law and Management', 'Female', 218)
# (2016, 'School of Business', 'Diploma in Law and Management', 'Male', 139)
# (2016, 'School of Business', 'Diploma in Leisure & Events Management', 'Female', 227)
# (2016, 'School of Business', 'Diploma in Leisure & Events Management', 'Male', 79)
# (2016, 'School of Business', 'Diploma in Leisure & Resort Management', 'Female', 120)
# (2016, 'School of Business', 'Diploma in Leisure & Resort Management', 'Male', 50)
# (2016, 'School of Business', 'Diploma in Logistics & Operations Management', 'Female', 122)
# (2016, 'School of Business', 'Diploma in Logistics & Operations Management', 'Male', 94)
# (2016, 'School of Business', 'Diploma in Marketing', 'Female', 100)
# (2016, 'School of Business', 'Diploma in Marketing', 'Male', 92)
# (2016, 'School of Business', 'Diploma in Retail Management', 'Female', 197)
# (2016, 'School of Business', 'Diploma in Retail Management', 'Male', 60)
# (2016, 'School of Design', 'Diploma in Apparel Design & Merchandising', 'Female', 156)
# (2016, 'School of Design', 'Diploma in Apparel Design & Merchandising', 'Male', 24)
# (2016, 'School of Design', 'Diploma in Communication Design', 'Female', 261)
# (2016, 'School of Design', 'Diploma in Communication Design', 'Male', 69)
# (2016, 'School of Design', 'Diploma in Digital Film & Television', 'Female', 133)
# (2016, 'School of Design', 'Diploma in Digital Film & Television', 'Male', 98)
# (2016, 'School of Design', 'Diploma in Environment Design', 'Female', 78)
# (2016, 'School of Design', 'Diploma in Environment Design', 'Male', 50)
# (2016, 'School of Design', 'Diploma in Interactive Media Design', 'Male', 2)
# (2016, 'School of Design', 'Diploma in Interior Architecture & Design', 'Female', 124)
# (2016, 'School of Design', 'Diploma in Interior Architecture & Design', 'Male', 77)
# (2016, 'School of Design', 'Diploma in Product & Industrial Design', 'Female', 67)
# (2016, 'School of Design', 'Diploma in Product & Industrial Design', 'Male', 71)
# (2016, 'School of Design', 'Diploma in Retail & Hospitality Design', 'Female', 96)
# (2016, 'School of Design', 'Diploma in Retail & Hospitality Design', 'Male', 37)
# (2016, 'School of Design', 'Diploma in Visual Communication', 'Female', 3)
# (2016, 'School of Design', 'Diploma in Visual Communication', 'Male', 5)
# (2016, 'School of Engineering', 'Common Engineering Programme', 'Female', 36)
# (2016, 'School of Engineering', 'Common Engineering Programme', 'Male', 161)
# (2016, 'School of Engineering', 'Diploma in 3D Interactive Media Technology', 'Female', 54)
# (2016, 'School of Engineering', 'Diploma in 3D Interactive Media Technology', 'Male', 90)
# (2016, 'School of Engineering', 'Diploma in Aerospace Electronics', 'Female', 57)
# (2016, 'School of Engineering', 'Diploma in Aerospace Electronics', 'Male', 326)
# (2016, 'School of Engineering', 'Diploma in Aerospace Engineering', 'Female', 39)
# (2016, 'School of Engineering', 'Diploma in Aerospace Engineering', 'Male', 355)
# (2016, 'School of Engineering', 'Diploma in Aviation Management & Services', 'Female', 153)
# (2016, 'School of Engineering', 'Diploma in Aviation Management & Services', 'Male', 341)
# (2016, 'School of Engineering', 'Diploma in Biomedical Engineering', 'Female', 104)
# (2016, 'School of Engineering', 'Diploma in Biomedical Engineering', 'Male', 129)
# (2016, 'School of Engineering', 'Diploma in Biomedical Informatics & Engineering', 'Male', 2)
# (2016, 'School of Engineering', 'Diploma in Business Process & Systems Engineering', 'Female', 215)
# (2016, 'School of Engineering', 'Diploma in Business Process & Systems Engineering', 'Male', 269)
# (2016, 'School of Engineering', 'Diploma in Clean Energy', 'Female', 57)
# (2016, 'School of Engineering', 'Diploma in Clean Energy', 'Male', 155)
# (2016, 'School of Engineering', 'Diploma in Computer Engineering', 'Female', 21)
# (2016, 'School of Engineering', 'Diploma in Computer Engineering', 'Male', 158)
# (2016, 'School of Engineering', 'Diploma in Electronics', 'Female', 71)
# (2016, 'School of Engineering', 'Diploma in Electronics', 'Male', 290)
# (2016, 'School of Engineering', 'Diploma in Green Building & Sustainability', 'Female', 147)
# (2016, 'School of Engineering', 'Diploma in Green Building & Sustainability', 'Male', 176)
# (2016, 'School of Engineering', 'Diploma in Infocomm & Network Engineering', 'Female', 51)
# (2016, 'School of Engineering', 'Diploma in Infocomm & Network Engineering', 'Male', 187)
# (2016, 'School of Engineering', 'Diploma in Integrated Facility Management', 'Female', 232)
# (2016, 'School of Engineering', 'Diploma in Integrated Facility Management', 'Male', 127)
# (2016, 'School of Engineering', 'Diploma in Mechatronics', 'Female', 65)
# (2016, 'School of Engineering', 'Diploma in Mechatronics', 'Male', 440)
# (2016, 'School of Engineering', 'Diploma in Media & Communication Technology', 'Female', 33)
# (2016, 'School of Engineering', 'Diploma in Media & Communication Technology', 'Male', 47)
# (2016, 'School of Engineering', 'Diploma in Microelectronics', 'Female', 8)
# (2016, 'School of Engineering', 'Diploma in Microelectronics', 'Male', 36)
# (2016, 'School of Engineering', 'Electrical & Electronic Engineering Programme', 'Female', 27)
# (2016, 'School of Engineering', 'Electrical & Electronic Engineering Programme', 'Male', 117)
# (2016, 'School of Engineering', 'Mechatronics/Aerospace Engineering', 'Female', 13)
# (2016, 'School of Engineering', 'Mechatronics/Aerospace Engineering', 'Male', 152)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Early Childhood Studies', 'Female', 349)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Early Childhood Studies', 'Male', 19)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Gerontological Management Studies', 'Female', 131)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Gerontological Management Studies', 'Male', 45)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Psychology Studies', 'Female', 141)
# (2016, 'School of Humanities & Social Sciences', 'Diploma in Psychology Studies', 'Male', 59)
#
# Executing: SELECT MAX(count) FROM enrolment where gender = 'Female' and year = 2017
# (454,)
#
# Executing: SELECT MIN(count) FROM enrolment where gender = 'Male' and year = 2016
# (2,)
#
# Executing: UPDATE enrolment SET course_name = 'Diploma in Cyber and Digital Security' WHERE course_name = 'Diploma in Cypher & Digital Security'
# Executing: UPDATE enrolment SET count = count + 5 WHERE course_name = 'School of Design' and year = 2017

# %% [markdown]
# ## Exercise 10.5  2020/A Level/P2/Q4 H2 Computing (Modified)
# A school has used a text file to store data collected about people who work at the school and students who attend the school. People who have a teaching role at the school are referred to as 'staff'. The school decides to transfer this information into a database.
#
# A web page will then be used to summarise the data. Different information will be visible on the web page, depending on the type of person displayed.
#
# ### Task 1
#
# Create an SQL file called `TASK4_1_<your name>_<center number>_<index number>.sql` to show the SQL code to create database `school.db` with the single table, `People`.
#
# The table will have the following fields of the given SQLite types:
# - `PersonID` - primary key, an auto-incremented integer
# - `FullName` - the full name of the person, text
# - `DateOfBirth` - the person's date of birth, text
# - `ScreenName` - the person's screen name, text
# - `IsAdult` - a Boolean using 0 for False and 1 for True, integer.
#
# Save your SQL code as
#
# `TASK4_1_<your name>_<center number>_<index number>.sql`
# <div style="text-align: right">[4]</div>

# %%
CREATE TABLE IF NOT EXISTS People(PersonID INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT, FullName TEXT NOT NULL, DateOfBirth TEXT NOT NULL, ScreenName TEXT NOT NULL, IsAdult INTEGER CHECK (IsAdult IN (0,1)))

# %% [markdown]
# ### Task  2
#
# The school wants to use the Python programming language and object-oriented programming to help publish the database content on a web page.
#
# The class `Person` will store the following data:
# - `full_name` - stored as a string
# - `date_of_birth` - initiliased with a string with the format YYYY-MM–DD
#
# The class has two methods defined on it:
# - `is_adult()` - returns a Boolean value to indicate whether the person is an adult or not. It:
#     - subtracts the year of the `date_of_birth` from the year of today's date
#     – returns True if the result is greater than 18, otherwise returns False.
#
# - `screen_name()` - returns a string which creates an identifier to be used as a screen name, which should be construted as follows:
#     – the full name with all spaces and punctuation removed
#     – followed by the two-digit month of their birth
#     – then the two-digit day of their birth.
#
# For example, John Tan, born on the $1^{\text{st}}$ of June 2000 (`“2000-06-01”`), would have the screen name `“JohnTan0601”`
#
# Save your program code as
#
# `TASK4_2_<your name>_<centre number>_<index number>.py`
# <div style="text-align: right">[7]</div>

# %%
from datetime import date
import string

class Person:
    def __init__(self,full_name,date_of_birth):
        self.full_name = full_name
        self.date_of_birth = date_of_birth
    
    def is_adult(self):
        current_year,_ = date.today().split("-",max=1)
        birth_year,_ = self.date_of_birth.split("-",max=1)
        return current_year - birth_year > 18

    def screen_name(self):
        Y,M,D = self.date_of_birth.split("-")
        name = self.full_name
        for i in string.punctuation:
            name = name.replace("i","")
        name = name.replace(" ","")
        return name+M+D
            

johnny = Person("John Tan","2000-06-01")
print(johnny.screen_name())
# Out:
# JohnTan0601

# %% [markdown]
# The `Staff` class inherits from `Person`, such that:
# - `screen_name()` should be the name followed by `“Staff”`
# - `is_adult()` always returns True.
#
# The `Student` class inherits from `Person`, such that the `is_adult()` method always returns False.
#
# Add your program code to
#
# `TASK4_2_<your name>_<centre number>_<index number>.py`
# <div style="text-align: right">[4]</div>
#
# The text file, `people.txt`, contains data items for a number of people. Each data item is separated by a comma, with each person's data on a new line as follows:
# - full name
# - date of birth in the form YYYY-MM-DD
# - a string indicating whether the person is `“Staff”`, `“Student”` or `“Person”`.
#
# Write program code to read in the information from the text file, `people.txt`, creating instance of the appropriate class for each person (either `Staff`, `Student` or `Person`).
# <div style="text-align: right">[4]</div>
#
# Write program code to insert all information from the file into the `school.db` database.
#
# Run the program.
#
# Add your program code to
#
# `TASK4_2_<your name>_<centre number>_<index number>.py`
# <div style="text-align: right">[8]</div>

# %% [markdown]
# ## Exercise 10.6  2021/A Level/P2/Q4 H2 Computing
#
# A competition has three qualifying rounds. Competitors could score up to 100 points in each round. Each competitor has a unique ID number. The competitor's ID. name. and the scores for
# each round are held in a database `Task4.db`, provided with this question.
#
# There are two tables:
# - `competitor (<u>id</u>, name)`
# - `scores (<u>id</u>, <u>round</u>, score)`
#
# Not every competitor competed in all three rounds. but they did all compete in round 1.
#
# ### Task 4.1
# Write a Python program and the necessary files to create a web application. The web application offers the following menu options:
# Round 1 Scores
# Round 2 Scores
# Round 3 Scores
# Mean Scores
# Qualifiers
#
# Save your program code as
# `Task4_l_<your name>_<centre number>_<index_number>.py`
#
# With any additional files/subfolders as needed in a folder named
# `Task4_l_<your name>_<centre number>_<index_number>`
#
# Run the web application and save the output of the program as
# `Task4_l_<your name>_<centre number>_<index_number>.html`
# <div style="text-align: right">[3]</div>

# %%
##YOUR ANSWER HERE

# %% [markdown]
# ## Task 4.2
#
# Write an SQL query that. for a given round number. shows:
#
# - competitor names and their scores for that particular round
# - only those who had a score for that round _
# - the scores sorted in descending order.
#
# The results of the query should be shown on a web page in a table that:
#
# - lists the name of each competitor and their score
# - has the results shown in descending order of the competitor's score.
#
# The resulting web page for each round should be accessed from the corresponding menu option from Task 4.1.
#
# Save all your SQL code as
#
# `Task4_2<your name>_<centre number>_<index_number>.sql`
#
# With any additional files/subfolders as needed in a folder named
#
# `Task4_2_<your name>_<centre number>_<index_number>`
# <div style="text-align: right">[6]</div>
#
# Run the web application and save the output of the program as
#
# `Task4_2_<your name>_<centre number>_<index_number>_1.html`
#
# `Task4_2_<your name>_<centre number>_<index_number>_2.html`
#
# `Task4_2_<your neme>_<centre number>_<index_number>_3.html`
#
# <div style="text-align: right">[2]</div>

# %%
## YOUR ANSWER HERE

# %% [markdown]
# ## Task 4.3
#
# Write a SQL query that shows:
#
# - competitor name
# - the mean score for each competitor, based on the number of rounds in which they competed.
#
# The query's results should be shown on a web page in a table that:
#
# - lists the name of each competitor and their mean score (to 2 decimal places)
# - has the results shown in ascending alphabetical order of the competitor's name.
#
# The resulting web page should be accessed from the corresponding menu option from Task 4.1.
#
# Save your SQL code as
#
# `Task4_3_<your name >_<centre nu:nbe:>_<index_number>.sql`
#
# With any additional files/subfolders as needed in a folder named
#
# `Task4_3_<your name>_<cent re number>_<index_numbwer>`
# <div style="text-align: right">[6]</div>
#
# Run the web application and save the output of the program as
#
# `Task4_3_<your name>_<centre number>_<index_number>.html>`
# <div style="text-align: right">[2]</div>

# %%
## YOUR ANSWER HERE

# %% [markdown]
# ## Task 4.4
#
# In order to qualify for the final of the competition. competitors need to score over 250. in total, in the first three rounds.
#
# Write a SQL query that shows:
#
# - competitor's name
# - their total score
# - whether that competitor has qualified for the final.
#
# The results of the query should be shown on a web page in a table that:
#
# - lists the names of the competitors. their scores and whether they qualified
# - has the results shown in descending order of the competitor's score.
#
# The resulting web page should be accessed from the corresponding menu option from Task 4.1.
#
# Save your SQL code as
#
# `Task4_4_<your name>_<centre number>_<index_number>.sql`
#
# With any additional files/subfolders as needed in a folder named
#
# `Task4_4_<your name>_<centre number>_< index_number>`
# <div style="text-align: right">[6]</div>
#
# Run the web application and save the output of the program as
#
# `Task4_4_<ycur name>_<centre number>_<index_number>.html`
# <div style="text-align: right">[2]</div>

# %%
##YOUR ANSWER HERE
